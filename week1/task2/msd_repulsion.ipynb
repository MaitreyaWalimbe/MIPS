# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("msd_repulsion.dat")

# %%
t = data[:, 0]
msd = data[:, 1]

plt.figure()
plt.plot(t, msd)
plt.xlabel("Time")
plt.ylabel("MSD")
plt.title("Mean Squared Displacement")
plt.grid()
plt.show()
